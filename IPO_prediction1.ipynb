# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import layers
from sklearn.model_selection import train_test_split

# %%
import pandas as pd

# Load the Excel file
df = pd.read_excel('/content/Initial Public Offering (Updated).xlsx')

display(df.head())
display(df.tail())
display(df.info())
display(df.describe())
# Out:
#         Date               IPO_Name  Issue_Size(crores)    QIB    HNI   RII  \
# 0 2026-05-14  Bagmane Prime Offi...             3405.00  17.09  15.79  0.00
# 1 2026-05-08  Onemi Technology S...              925.92  24.87   6.57  2.03
# 2 2026-04-29  Citius Transnet In...             1105.00   8.54  11.77  0.00
# 3 2026-04-17  Om Power Transmiss...              150.06   3.65   7.06  1.54
# 4 2026-04-02  Sai Parenteral's L...              408.79   1.71   2.36  0.12
#
#    Total  Offer Price  List Price  Listing Gain  CMP(BSE)  CMP(NSE)  \
# 0  16.50          100       103.4          3.40    103.92    103.97
# 1   9.50          171       191.0         11.70    231.70    231.74
# 2  10.01          100       104.5          4.50    105.87    106.04
# 3   3.33          175       181.1          3.49    190.80    190.74
# 4   1.05          392       405.0          3.32    487.10    486.70
#
#    Current Gains
# 0           3.92
# 1          35.50
# 2           5.87
# 3           9.03
# 4          24.26
#           Date                             IPO_Name  Issue_Size(crores)  \
# 647 2010-02-03  Infinite Computer Solutions Limited              189.80
# 648 2010-01-06                     D B Corp Limited              384.22
# 649 2010-01-05            Godrej Properties Limited              468.85
# 650 2010-01-04                   JSW Energy Limited             2700.00
# 651 2010-01-11           MBL Infrastructure Limited              102.60
#
#        QIB     HNI    RII  Total  Offer Price  List Price  Listing Gain  \
# 647  48.44  106.02  11.08  43.22          165      178.35          8.09
# 648  68.52   26.17   3.42  39.54          212      250.00         17.92
# 649   7.45    0.41   0.38   4.00          490      510.00          4.08
# 650   2.88    0.15   0.40   1.68          100      102.00          2.00
# 651   3.35    2.65   0.40   1.97          180      190.00          5.56
#
#      CMP(BSE)  CMP(NSE)  Current Gains
# 647    473.75    473.75         187.12
# 648    274.75    273.00          29.60
# 649   1956.80   1952.10         299.35
# 650    536.30    536.40         436.30
# 651     40.75     40.78         -77.36
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 652 entries, 0 to 651
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Date                652 non-null    datetime64[ns]
#  1   IPO_Name            652 non-null    object
#  2   Issue_Size(crores)  652 non-null    float64
#  3   QIB                 650 non-null    float64
#  4   HNI                 650 non-null    float64
#  5   RII                 650 non-null    float64
#  6   Total               650 non-null    float64
#  7   Offer Price         652 non-null    int64
#  8   List Price          652 non-null    float64
#  9   Listing Gain        650 non-null    float64
#  10  CMP(BSE)            650 non-null    float64
#  11  CMP(NSE)            642 non-null    float64
#  12  Current Gains       649 non-null    float64
# dtypes: datetime64[ns](1), float64(10), int64(1), object(1)
# memory usage: 66.3+ KB
# None
#                                 Date  Issue_Size(crores)         QIB  \
# count                            652          652.000000  650.000000
# mean   2020-02-06 22:40:29.447852800         1444.556396   48.771169
# min              2010-01-04 00:00:00           23.000000    0.000000
# 25%              2016-05-09 18:00:00          269.477500    2.630000
# 50%              2021-11-18 00:00:00          599.785000   13.595000
# 75%              2024-09-24 00:00:00         1272.290000   77.295000
# max              2026-05-14 00:00:00        27858.800000  420.570000
# std                              NaN         2628.744869   66.549173
#
#               HNI         RII       Total  Offer Price   List Price  \
# count  650.000000  650.000000  650.000000   652.000000   652.000000
# mean    71.257385   15.913738   37.167046   358.694785   419.785690
# min      0.000000    0.000000    0.110000    10.000000     0.000000
# 25%      1.840000    1.402500    2.260000   121.750000   135.075000
# 50%     13.350000    4.780000   10.765000   252.000000   286.625000
# 75%     76.345000   14.610000   56.617500   481.250000   548.500000
# max    958.070000  374.810000  326.490000  2165.000000  2725.000000
# std    130.586078   32.483974   52.977874   326.819563   415.339727
#
#        Listing Gain      CMP(BSE)      CMP(NSE)  Current Gains
# count    650.000000    650.000000    642.000000     649.000000
# mean      16.480338    633.441831    644.354019      73.202761
# min      -38.890000      0.040000      0.050000     -99.930000
# 25%       -0.065000    119.925000    121.172500     -33.200000
# 50%        5.800000    285.750000    288.250000      12.310000
# 75%       23.060000    671.050000    706.012500      91.380000
# max      252.760000  15924.100000  15892.000000    2523.670000
# std       30.721293   1141.908775   1148.343680     243.124515

# %%
df.isnull().sum()
# Out:
# Date                   0
# IPO_Name               0
# Issue_Size(crores)     0
# QIB                    2
# HNI                    2
# RII                    2
# Total                  2
# Offer Price            0
# List Price             0
# Listing Gain           2
# CMP(BSE)               2
# CMP(NSE)              10
# Current Gains          3
# dtype: int64

# %%
#removing nulls from data

# Drop rows where critical listing data is missing
df_cleaned = df.dropna(subset=['Total', 'Listing Gain', 'CMP(BSE)'])

# Fill missing NSE prices with the corresponding BSE price
df_cleaned['CMP(NSE)'] = df_cleaned['CMP(NSE)'].fillna(df_cleaned['CMP(BSE)'])

df_cleaned = df_cleaned.dropna(subset=['Current Gains'])
df_cleaned.isnull().sum()
# Out:
# /tmp/ipykernel_1230/3954536573.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cleaned['CMP(NSE)'] = df_cleaned['CMP(NSE)'].fillna(df_cleaned['CMP(BSE)'])
# Date                  0
# IPO_Name              0
# Issue_Size(crores)    0
# QIB                   0
# HNI                   0
# RII                   0
# Total                 0
# Offer Price           0
# List Price            0
# Listing Gain          0
# CMP(BSE)              0
# CMP(NSE)              0
# Current Gains         0
# dtype: int64

# %%
#creates new column (listing gain profit) w/ 0 (loss) & 1 (profit)
df_cleaned['Listing_gains_profit']=np.where(df_cleaned['Listing Gain']>0,1,0)
df_cleaned['Listing_gains_profit'].describe()
# Out:
# count    645.000000
# mean       0.683721
# std        0.465384
# min        0.000000
# 25%        0.000000
# 50%        1.000000
# 75%        1.000000
# max        1.000000
# Name: Listing_gains_profit, dtype: float64

# %%
#remove columns to avoid data leakage ,axis=1 to delete columns not rows
df_cleaned=df_cleaned.drop(['Date','IPO_Name','Listing Gain','List Price','CMP(BSE)','CMP(NSE)','Current Gains'], axis=1, errors='ignore')
df_cleaned.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_5056/1078437395.py in <cell line: 0>()
# ----> 1 df_cleaned=df_cleaned.drop(['Date','IPO_Name','Listing Gain','List Price','CMP(BSE)','CMP(NSE)','Current Gains'], axis=1, errors='ignore')
#       2 df_cleaned.info()
#
# NameError: name 'df_cleaned' is not defined

# %%
#visualising target variable
sns.countplot(x='Listing_gains_profit', data=df_cleaned)
plt.title('Distribution of IPO listing profit category')
plt.xlabel('Listing Profit(no=0, yes=1)')
plt.ylabel('Count')
plt.show()

# %%
df_cleaned.hist(bins=30, figsize=(12,10))
plt.show()

# %%
for col in ['Issue_Size(crores)', 'QIB','HNI','RII','Total','Offer Price']:
  sns.boxplot(data=df_cleaned, y=col)
  plt.title(f'Box Plot of {col}')
  plt.show()

# %%
for col in ['Issue_Size(crores)', 'QIB','HNI','RII','Total','Offer Price']:
  sns.boxplot(data=df_cleaned,x='Listing_gains_profit', y=col)
  plt.title(f'Box Plot of {col} with respect to listing gains type')
  plt.xlabel('Listing profit (no=0, yes=1)')
  plt.show()

# %%
#positive skew-> tail towards right
print(df_cleaned.skew())
# Out:
# Issue_Size(crores)      4.642241
# QIB                     1.711949
# HNI                     3.148485
# RII                     4.898248
# Total                   2.184687
# Offer Price             1.928786
# Listing_gains_profit   -0.792001
# dtype: float64

# %%
correlation=df_cleaned.corr()
sns.heatmap(correlation, cmap='Blues', annot=True)
plt.show()

# %%
## alpha- to control transparency of the scatter dots
# independent_vars=df_cleaned[['Issue_Size(crores)', 'QIB','HNI','RII','Total','Offer Price']]
# sns.pairplot(independent_vars, kind='scatter', plot_kws={'alpha':0.4})

# %%
#IQR (interquartile range method)
q1=df_cleaned['Issue_Size(crores)'].quantile(q=0.25)
q3=df_cleaned['Issue_Size(crores)'].quantile(q=0.75)
iqr=q3-q1
lower=q1-1.5*iqr
upper=q3+1.5*iqr
print('iqr=', iqr, '\nlower=',lower, '\nupper=', upper, sep='')

df_cleaned['Issue_Size(crores)']=df_cleaned['Issue_Size(crores)'].clip(lower,upper)
df_cleaned['Issue_Size(crores)'].describe()
# Out:
# iqr=985.9
# lower=-1214.75
# upper=2728.85
# count     645.000000
# mean      934.021116
# std       878.984950
# min        23.000000
# 25%       264.100000
# 50%       596.410000
# 75%      1250.000000
# max      2728.850000
# Name: Issue_Size(crores), dtype: float64

# %%
q1=df_cleaned['QIB'].quantile(q=0.25)
q3=df_cleaned['QIB'].quantile(q=0.75)
iqr=q3-q1
lower=q1-1.5*iqr
upper=q3+1.5*iqr
print('iqr=', iqr, '\nlower=',lower, '\nupper=', upper, sep='')

df_cleaned['QIB']=df_cleaned['QIB'].clip(lower,upper)
df_cleaned['QIB'].describe()
# Out:
# iqr=74.27
# lower=-108.785
# upper=188.29500000000002
# count    645.000000
# mean      46.382023
# std       59.631566
# min        0.000000
# 25%        2.620000
# 50%       13.470000
# 75%       76.890000
# max      188.295000
# Name: QIB, dtype: float64

# %%
q1=df_cleaned['HNI'].quantile(q=0.25)
q3=df_cleaned['HNI'].quantile(q=0.75)
iqr=q3-q1
lower=q1-1.5*iqr
upper=q3+1.5*iqr
print('iqr=', iqr, '\nlower=',lower, '\nupper=', upper, sep='')

df_cleaned['HNI']=df_cleaned['HNI'].clip(lower,upper)
df_cleaned['HNI'].describe()
# Out:
# iqr=74.31
# lower=-109.625
# upper=187.615
# count    645.000000
# mean      49.775605
# std       66.026189
# min        0.000000
# 25%        1.840000
# 50%       13.230000
# 75%       76.150000
# max      187.615000
# Name: HNI, dtype: float64

# %%
q1=df_cleaned['RII'].quantile(q=0.25)
q3=df_cleaned['RII'].quantile(q=0.75)
iqr=q3-q1
lower=q1-1.5*iqr
upper=q3+1.5*iqr
print('iqr=', iqr, '\nlower=',lower, '\nupper=', upper, sep='')

df_cleaned['RII']=df_cleaned['RII'].clip(lower,upper)
df_cleaned['RII'].describe()
# Out:
# iqr=13.23
# lower=-18.445
# upper=34.475
# count    645.000000
# mean      10.059884
# std       11.602269
# min        0.000000
# 25%        1.400000
# 50%        4.780000
# 75%       14.630000
# max       34.475000
# Name: RII, dtype: float64

# %%
q1=df_cleaned['Total'].quantile(q=0.25)
q3=df_cleaned['Total'].quantile(q=0.75)
iqr=q3-q1
lower=q1-1.5*iqr
upper=q3+1.5*iqr
print('iqr=', iqr, '\nlower=',lower, '\nupper=', upper, sep='')

df_cleaned['Total']=df_cleaned['Total'].clip(lower,upper)
df_cleaned['Total'].describe()
# Out:
# iqr=54.42
# lower=-79.36999999999999
# upper=138.31
# count    645.000000
# mean      33.668109
# std       42.167840
# min        0.110000
# 25%        2.260000
# 50%       10.730000
# 75%       56.680000
# max      138.310000
# Name: Total, dtype: float64

# %%
q1=df_cleaned['Offer Price'].quantile(q=0.25)
q3=df_cleaned['Offer Price'].quantile(q=0.75)
iqr=q3-q1
lower=q1-1.5*iqr
upper=q3+1.5*iqr
print('iqr=', iqr, '\nlower=',lower, '\nupper=', upper, sep='')

df_cleaned['Offer Price']=df_cleaned['Offer Price'].clip(lower,upper)
df_cleaned['Offer Price'].describe()
# Out:
# iqr=355.0
# lower=-412.5
# upper=1007.5
# count     645.000000
# mean      341.399225
# std       274.525408
# min        10.000000
# 25%       120.000000
# 50%       252.000000
# 75%       475.000000
# max      1007.500000
# Name: Offer Price, dtype: float64

# %%
print(df_cleaned.skew())
# Out:
# Issue_Size(crores)      1.082785
# QIB                     1.238406
# HNI                     1.216743
# RII                     1.205502
# Total                   1.293200
# Offer Price             1.050317
# Listing_gains_profit   -0.792001
# dtype: float64

# %%
#MinMaxScaler fitting (squishes every numerical column into btwn 0 & 1)
from sklearn.preprocessing import MinMaxScaler
target = 'Listing_gains_profit'
predictors = df_cleaned.drop(columns=[target]).columns
scaler = MinMaxScaler()
X_scaled = scaler.fit_transform(df_cleaned[predictors])
X_scaled_df = pd.DataFrame(X_scaled, columns=predictors)
X_scaled_df.describe()
# Out:
#        Issue_Size(crores)         QIB         HNI         RII       Total  \
# count          645.000000  645.000000  645.000000  645.000000  645.000000
# mean             0.336686    0.246326    0.265307    0.291802    0.242823
# std              0.324846    0.316692    0.351924    0.336542    0.305122
# min              0.000000    0.000000    0.000000    0.000000    0.000000
# 25%              0.089103    0.013914    0.009807    0.040609    0.015557
# 50%              0.211915    0.071537    0.070517    0.138651    0.076845
# 75%              0.453462    0.408349    0.405884    0.424365    0.409334
# max              1.000000    1.000000    1.000000    1.000000    1.000000
#
#        Offer Price
# count   645.000000
# mean      0.332230
# std       0.275213
# min       0.000000
# 25%       0.110276
# 50%       0.242607
# 75%       0.466165
# max       1.000000

# %%
#Train/Test split
from sklearn.model_selection import train_test_split

target = 'Listing_gains_profit'

X = X_scaled_df.values
y = df_cleaned[target].values

X_train, X_test, y_train, y_test = train_test_split(
    X, y,
    #test_size=0.30,
    test_size=0.20,
    random_state=42,
    #forces the split to have exact same ratio or winners(1) & losers (0)
    stratify=y
)

# 3. Print shapes to verify the sample counts
print("Training Features Shape:", X_train.shape)
print("Testing Features Shape :", X_test.shape)
print("Training Labels Size   :", y_train.shape)
print("Testing Labels Size    :", y_test.shape)
# Out:
# Training Features Shape: (516, 6)
# Testing Features Shape : (129, 6)
# Training Labels Size   : (516,)
# Testing Labels Size    : (129,)

# %% [markdown]
# Model 1: Feedforward Neural Network (Keras)

# %%
tf.random.set_seed(42)
model = tf.keras.Sequential()
model.add(tf.keras.layers.Dense(32, input_shape=(X_train.shape[1],), activation='relu'))
model.add(tf.keras.layers.Dense(16, activation='relu'))
model.add(tf.keras.layers.Dense(8, activation='relu'))
model.add(tf.keras.layers.Dense(4, activation='relu'))
model.add(tf.keras.layers.Dense(1, activation='sigmoid'))
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.compile(
    #optimizer is coach of neural network
    optimizer=tf.keras.optimizers.Adam(0.001),
    loss=tf.keras.losses.BinaryCrossentropy(),
    metrics=['accuracy', tf.keras.metrics.Recall()]
)
print(model.summary())
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 32)             │           224 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 16)             │           528 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 8)              │           136 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 4)              │            36 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 1)              │             5 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 929 (3.63 KB)
#  Trainable params: 929 (3.63 KB)
#  Non-trainable params: 0 (0.00 B)
# None

# %%
model.fit(X_train, y_train, epochs=250)
# Out:
# Epoch 1/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8663 - loss: 0.2740 - recall: 0.8782
# Epoch 2/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8702 - loss: 0.2737 - recall: 0.8782
# Epoch 3/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8702 - loss: 0.2730 - recall: 0.8782
# Epoch 4/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8624 - loss: 0.2744 - recall: 0.8697
# Epoch 5/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8702 - loss: 0.2722 - recall: 0.8782
# Epoch 6/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8624 - loss: 0.2729 - recall: 0.8725
# Epoch 7/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8721 - loss: 0.2716 - recall: 0.8810
# Epoch 8/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8721 - loss: 0.2719 - recall: 0.8810
# Epoch 9/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8663 - loss: 0.2712 - recall: 0.8725
# Epoch 10/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8702 - loss: 0.2713 - recall: 0.8782
# Epoch 11/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8663 - loss: 0.2719 - recall: 0.8725
# Epoch 12/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8721 - loss: 0.2703 - recall: 0.8810
# Epoch 13/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8663 - loss: 0.2713 - recall: 0.8725
# Epoch 14/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8663 - loss: 0.2696 - recall: 0.8725
# Epoch 15/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8663 - loss: 0.2709 - recall: 0.8754
# Epoch 16/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8663 - loss: 0.2702 - recall: 0.8725
# Epoch 17/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8721 - loss: 0.2692 - recall: 0.8810
# Epoch 18/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8663 - loss: 0.2696 - recall: 0.8782
# Epoch 19/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8643 - loss: 0.2688 - recall: 0.8725
# Epoch 20/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8682 - loss: 0.2701 - recall: 0.8782
# Epoch 21/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8702 - loss: 0.2693 - recall: 0.8782
# Epoch 22/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8682 - loss: 0.2690 - recall: 0.8782
# Epoch 23/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8682 - loss: 0.2690 - recall: 0.8782
# Epoch 24/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8682 - loss: 0.2679 - recall: 0.8782
# Epoch 25/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8702 - loss: 0.2685 - recall: 0.8810
# Epoch 26/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8682 - loss: 0.2685 - recall: 0.8725
# Epoch 27/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8721 - loss: 0.2676 - recall: 0.8810
# Epoch 28/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8643 - loss: 0.2687 - recall: 0.8725
# Epoch 29/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8702 - loss: 0.2677 - recall: 0.8782
# Epoch 30/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8721 - loss: 0.2679 - recall: 0.8782
# Epoch 31/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8682 - loss: 0.2670 - recall: 0.8782
# Epoch 32/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8721 - loss: 0.2666 - recall: 0.8810
# Epoch 33/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8702 - loss: 0.2667 - recall: 0.8782
# Epoch 34/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8740 - loss: 0.2662 - recall: 0.8782
# Epoch 35/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8702 - loss: 0.2666 - recall: 0.8782
# Epoch 36/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8721 - loss: 0.2662 - recall: 0.8782
# Epoch 37/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8702 - loss: 0.2674 - recall: 0.8782
# Epoch 38/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8721 - loss: 0.2657 - recall: 0.8810
# Epoch 39/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8663 - loss: 0.2669 - recall: 0.8725
# Epoch 40/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.
250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8915 - loss: 0.2302 - recall: 0.9008
# Epoch 242/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8915 - loss: 0.2288 - recall: 0.8980
# Epoch 243/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8915 - loss: 0.2287 - recall: 0.9008
# Epoch 244/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8895 - loss: 0.2297 - recall: 0.9008
# Epoch 245/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8973 - loss: 0.2286 - recall: 0.9065
# Epoch 246/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8876 - loss: 0.2291 - recall: 0.8952
# Epoch 247/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8992 - loss: 0.2272 - recall: 0.9065
# Epoch 248/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8934 - loss: 0.2294 - recall: 0.9037
# Epoch 249/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8973 - loss: 0.2274 - recall: 0.9037
# Epoch 250/250
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8953 - loss: 0.2281 - recall: 0.9065

# %%
model.evaluate(X_train, y_train)
# Out:
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7868 - loss: 0.4085 - recall_4: 0.8357
# [0.40847247838974, 0.786821722984314, 0.8356940746307373]

# %%
model.evaluate(X_test, y_test)
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7364 - loss: 0.5116 - recall_4: 0.7955
# [0.5115518569946289, 0.7364341020584106, 0.7954545617103577]

# %% [markdown]
# Model 2: XGBoost Classifier

# %%
from xgboost import XGBClassifier

# Initialize and train
xgb_model = XGBClassifier(n_estimators=100, learning_rate=0.05, max_depth=4, random_state=42)
xgb_model.fit(X_train, y_train)

# Predict and evaluate
xgb_preds = xgb_model.predict(X_test)

# %%
from sklearn.metrics import accuracy_score, classification_report

# Calculate final test accuracy
xgb_accuracy = accuracy_score(y_test, xgb_preds)
print(f"XGBoost Test Accuracy: {xgb_accuracy * 100:.2f}%\n")

# Display complete precision, recall, and f1-score details
print(classification_report(y_test, xgb_preds))
# Out:
# XGBoost Test Accuracy: 73.64%
#
#               precision    recall  f1-score   support
#
#            0       0.58      0.63      0.60        41
#            1       0.82      0.78      0.80        88
#
#     accuracy                           0.74       129
#    macro avg       0.70      0.71      0.70       129
# weighted avg       0.74      0.74      0.74       129

# %% [markdown]
# Model 3: LightGBM (Light Gradient Boosting Machine)

# %%
from lightgbm import LGBMClassifier

lgb_model = LGBMClassifier(n_estimators=100, learning_rate=0.05, max_depth=4, random_state=42, verbose=-1)
lgb_model.fit(X_train, y_train)
lgb_preds = lgb_model.predict(X_test)

lgb_accuracy = accuracy_score(y_test, lgb_preds)
print(f"LightGBM Test Accuracy: {lgb_accuracy * 100:.2f}%\n")
print(classification_report(y_test, lgb_preds))
# Out:
# LightGBM Test Accuracy: 75.97%
#
#               precision    recall  f1-score   support
#
#            0       0.62      0.61      0.62        41
#            1       0.82      0.83      0.82        88
#
#     accuracy                           0.76       129
#    macro avg       0.72      0.72      0.72       129
# weighted avg       0.76      0.76      0.76       129
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(

# %% [markdown]
# Model 4: Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report

rf_model = RandomForestClassifier(
    n_estimators=200,
    max_depth=5,
    random_state=42
)
rf_model.fit(X_train, y_train)

rf_preds = rf_model.predict(X_test)

rf_accuracy = accuracy_score(y_test, rf_preds)
print(f"Random Forest Test Accuracy: {rf_accuracy * 100:.2f}%\n")
print(classification_report(y_test, rf_preds))
# Out:
# Random Forest Test Accuracy: 77.52%
#
#               precision    recall  f1-score   support
#
#            0       0.63      0.71      0.67        41
#            1       0.86      0.81      0.83        88
#
#     accuracy                           0.78       129
#    macro avg       0.74      0.76      0.75       129
# weighted avg       0.78      0.78      0.78       129

# %%
import joblib
from google.colab import files

#trained Random Forest model object
joblib.dump(rf_model, 'best_rf_model.pkl')

#fitted MinMaxScaler object
joblib.dump(scaler, 'scaler.pkl')

files.download('best_rf_model.pkl')
files.download('scaler.pkl')
